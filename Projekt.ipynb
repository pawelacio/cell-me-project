# %% [markdown]
# # Ładowanie bibliotek

# %%
import pandas as pd
import numpy as np
import re
import nltk

RE_SPACES = re.compile("\s+")
RE_HASHTAG = re.compile("[@#][_a-z0-9]+")
RE_EMOTICONS = re.compile("(:-?\))|(:p)|(:d+)|(:-?\()|(:/)|(;-?\))|(<3)|(=\))|(\)-?:)|(:'\()|(8\))")
RE_HTTP = re.compile("http(s)?://[/\.a-z0-9]+")

# %%
test_data = pd.read_csv('test.csv', sep=',', na_values=['?'])
train_data = pd.read_csv('train.csv', sep=',', na_values=['?'])

# %% [markdown]
# # Informacje o danych
# a) przykładowe dane:

# %%
test_data.head(5)
# Out:
#        Id                                       Product Name Brand Name  \
# 0  202646  Huawei P8 Lite ALE-L23 Factory Unlocked 16GB L...     Huawei
# 1  202647  Huawei P8 Lite ALE-L23 Factory Unlocked 16GB L...     Huawei
# 2  202648  Huawei P8 Lite ALE-L23 Factory Unlocked 16GB L...     Huawei
# 3  202649  Huawei P8 Lite ALE-L23 Factory Unlocked 16GB L...     Huawei
# 4  202650  Huawei P8 Lite ALE-L23 Factory Unlocked 16GB L...     Huawei
#
#    Price                                            Reviews
# 0  184.9                                           Excelent
# 1  184.9                           Fit perfectly. Excelent.
# 2  184.9    It has a very good relation, price/performance.
# 3  184.9                                      Like it a lot
# 4  184.9  Dear , i had a problem wich the wifi senial !!...

# %% [markdown]
# b) rozmiar

# %%
test_data.shape
# Out:
# (211195, 5)

# %%
class Tokenizer():
    @staticmethod
    def tokenize(text):
        pass
    
class BeforeTokenizationNormalizer():
    @staticmethod
    def normalize(text):
        text = str(text)
        text = text.strip().lower()
        text = text.replace('&nbsp;', ' ')
        text = text.replace('&lt;', '<')
        text = text.replace('&gt;', '>')
        text = text.replace('&amp;', '&')
        text = text.replace('&pound;', u'£')
        text = text.replace('&euro;', u'€')
        text = text.replace('&copy;', u'©')
        text = text.replace('&reg;', u'®')
        return text

# %%
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

porter = nltk.PorterStemmer()

class NltkTokenizer(Tokenizer):
    @staticmethod
    def tokenize(text):
        text = nltk.word_tokenize(text)
        for w in range(len(text)):
            text[w] = porter.stem(text[w])
        return text

# %%
# for i in train_data.index:
#     review = BeforeTokenizationNormalizer.normalize(train_data.iat[i, 4])
#     words_nltk = NltkTokenizer.tokenize(review)
#     print(words_nltk)

# %%
from collections import Counter
words = Counter()

for i in train_data.index:
    review = BeforeTokenizationNormalizer.normalize(train_data.iat[i, 4])
    words.update(NltkTokenizer.tokenize(review))

# %%
words.most_common()
# Out:
# [('.', 388832),
#  ('the', 337576),
#  ('i', 261670),
#  ('it', 249429),
#  (',', 236959),
#  ('phone', 201344),
#  ('and', 199329),
#  ('a', 178419),
#  ('to', 172959),
#  ('is', 136464),
#  ('thi', 105022),
#  ('for', 94337),
#  ('!', 87733),
#  ('wa', 79360),
#  ('not', 78951),
#  ('with', 76175),
#  ('my', 75552),
#  ('of', 72734),
#  ('in', 67759),
#  ('that', 65872),
#  ('but', 63489),
#  ('work', 59462),
#  ('on', 58620),
#  ("n't", 55743),
#  ('have', 55429),
#  ('you', 51284),
#  ('great', 47260),
#  ('good', 47014),
#  ('use', 44314),
#  ('as', 43843),
#  ('veri', 42679),
#  ('so', 39681),
#  ("'s", 35530),
#  ('be', 33063),
#  ('had', 31573),
#  ('no', 30453),
#  ('like', 30092),
#  ('do', 30018),
#  ('one', 28659),
#  ('all', 28207),
#  ('get', 27301),
#  ('love', 27256),
#  ('screen', 26600),
#  ('at', 26476),
#  ('me', 26324),
#  (')', 25590),
#  ('just', 25285),
#  ('would', 24439),
#  ('batteri', 23981),
#  ('...', 23777),
#  ('or', 23697),
#  ('(', 23475),
#  ('from', 23405),
#  ('if', 23160),
#  ('can', 22928),
#  ('an', 22846),
#  ('ha', 22801),
#  ('new', 22503),
#  ('are', 22469),
#  ('when', 21164),
#  ('time', 20760),
#  ('iphon', 20474),
#  ('will', 20356),
#  ('onli', 20309),
#  ('doe', 19973),
#  ('price', 19333),
#  ('product', 19073),
#  ('did', 18725),
#  ('buy', 18631),
#  ('they', 18297),
#  ('up', 17596),
#  ('out', 16750),
#  ('than', 16469),
#  ('look', 16368),
#  ('realli', 16122),
#  ('app', 16083),
#  ('card', 15939),
#  ('problem', 15828),
#  ('about', 15739),
#  ('sim', 15700),
#  ('excel', 15247),
#  ('day', 15207),
#  ('bought', 15173),
#  ('camera', 15114),
#  ('what', 14968),
#  ('got', 14638),
#  ('am', 14630),
#  ('well', 14317),
#  ('becaus', 14267),
#  ('after', 14240),
#  ('purchas', 13807),
#  ('other', 13801),
#  ('even', 13662),
#  ('more', 13587),
#  ('there', 13557),
#  ("'m", 13500),
#  ('charg', 13166),
#  (':', 13060),
#  ('back', 13010),
#  ('need', 12995),
#  ('now', 12774),
#  ('could', 12682),
#  ('nice', 12649),
#  ('blu', 12518),
#  ('call', 12401),
#  ('came', 11863),
#  ('watch', 11630),
#  ('want', 11612),
#  ('which', 11576),
#  ('unlock', 11414),
#  ('ani', 11221),
#  ('also', 10992),
#  ('go', 10944),
#  ('qualiti', 10883),
#  ('expect', 10878),
#  ('your', 10874),
#  ('month', 10860),
#  ('much', 10699),
#  ('fast', 10514),
#  ('receiv', 10491),
#  ('some', 10481),
#  ('recommend', 10281),
#  ('better', 10105),
#  ('$', 10075),
#  ('been', 10037),
#  ('still', 9907),
#  ("''", 9795),
#  ('everyth', 9737),
#  ('thing', 9600),
#  ('make', 9536),
#  ('return', 9460),
#  ('perfect', 9403),
#  ('issu', 9380),
#  ('take', 9338),
#  ('say', 9290),
#  ('by', 9208),
#  ('tri', 9185),
#  ('first', 9155),
#  ('off', 8942),
#  ('life', 8940),
#  ('then', 8921),
#  ('come', 8893),
#  ('seller', 8858),
#  ('2', 8857),
#  ("'ve", 8776),
#  ('``', 8765),
#  ('&', 8684),
#  ('devic', 8638),
#  ('far', 8585),
#  ('android', 8556),
#  ('thank', 8517),
#  ('-', 8453),
#  ('money', 8413),
#  ('appl', 8394),
#  ('happi', 8282),
#  ('condit', 8057),
#  ('we', 7962),
#  ('too', 7946),
#  ('servic', 7930),
#  ('case', 7898),
#  ('ca', 7857),
#  ('turn', 7751),
#  ('them', 7702),
#  ('amazon', 7604),
#  ('charger', 7444),
#  ('littl', 7338),
#  ('order', 7322),
#  ('best', 7310),
#  ('set', 7307),
#  ('?', 7282),
#  ('last', 7270),
#  ('fine', 7146),
#  ('brand', 7064),
#  ('never', 6972),
#  ('replac', 6919),
#  ('review', 6917),
#  ('lot', 6865),
#  ('week', 6859),
#  ('how', 6834),
#  ('featur', 6778),
#  ('bad', 6724),
#  ('few', 6707),
#  ('two', 6687),
#  ('know', 6644),
#  ('again', 6536),
#  ('updat', 6375),
#  ('easi', 6368),
#  ('anoth', 6339),
#  ('5', 6282),
#  ('were', 6220),
#  ('t', 6217),
#  ('over', 6206),
#  ('seem', 6117),
#  ('big', 6097),
#  ('he', 6039),
#  ('way', 6034),
#  ('pictur', 6027),
#  ('year', 5917),
#  ('box', 5909),
#  ('think', 5878),
#  ('3', 5876),
#  ('sinc', 5869),
#  ('without', 5839),
#  ('arriv', 5811),
#  ('text', 5704),
#  ('connect', 5660),
#  ('same', 5602),
#  ('befor', 5579),
#  ('pretti', 5523),
#  ('button', 5497),
#  ('give', 5475),
#  ('speaker', 5433),
#  ('she', 5428),
#  ('said', 5390),
#  ('see', 5388),
#  ('start', 5373),
#  ('item', 5365),
#  ('right', 5319),
#  ('old', 5268),
#  ('run', 5263),
#  ('amaz', 5215),
#  ('ship', 5206),
#  ('%', 5192),
#  ('find', 5187),
#  ('feel', 5175),
#  ('cell', 5166),
#  ('activ', 5129),
#  ('blackberri', 5083),
#  ('awesom', 5057),
#  ('abl', 5024),
#  ('4', 5011),
#  ('scratch', 4985),
#  ('while', 4978),
#  ('ever', 4977),
#  ('howev', 4928),
#  ('ok', 4917),
#  ('keep', 4900),
#  ('disappoint', 4899),
#  ('put', 4888),
#  ('though', 4873),
#  ('star', 4815),
#  ('sound', 4809),
#  ('should', 4753),
#  ('samsung', 4737),
#  ('size', 4733),
#  ('their', 4720),
#  ('pleas', 4689),
#  ('function', 4674),
#  ('send', 4654),
#  ('most', 4639),
#  ('play', 4551),
#  ('excelent', 4538),
#  ('store', 4530),
#  ('mani', 4512),
#  ('memori', 4475),
#  ('hour', 4416),
#  ('differ', 4402),
#  ('took', 4394),
#  ('long', 4372),
#  ('sure', 4353),
#  ('custom', 4351),
#  ('who', 4315),
#  ('describ', 4275),
#  ('6', 4227),
#  ('down', 4220),
#  ('stop', 4171),
#  ('perfectli', 4169),
#  ('pay', 4141),
#  ('verizon', 4096),
#  ('touch', 4080),
#  ('these', 4067),
#  ('video', 4058),
#  ('everi', 4033),
#  ('el', 3996),
#  ('peopl', 3961),
#  ('made', 3957),
#  ('plu', 3955),
#  ('read', 3943),
#  ('power', 3941),
#  ('help', 3928),
#  ('deal', 3922),
#  ('sd', 3871),
#  ('went', 3869),
#  ('y', 3862),
#  ('compani', 3813),
#  ('enough', 3792),
#  ('own', 3781),
#  ('--', 3778),
#  ('someth', 3774),
#  ('into', 3762),
#  ('smartphon', 3746),
#  ('worth', 3739),
#  ('cheap', 3737),
#  ('here', 3720),
#  ('bit', 3718),
#  ('talk', 3717),
#  ('open', 3713),
#  ('definit', 3656),
#  ('htc', 3650),
#  ('upgrad', 3638),
#  ('actual', 3621),
#  ('small', 3612),
#  ('noth', 3612),
#  ('smart', 3598),
#  ('through', 3581),
#  ('reason', 3557),
#  (';', 3531),
#  ('t-mobil', 3512),
#  ('wifi', 3507),
#  ('hard', 3500),
#  ('end', 3497),
#  ('music', 3481),
#  ('drop', 3459),
#  ('advertis', 3448),
#  ('download', 3438),
#  ('instal', 3435),
#  ('anyth', 3435),
#  ('light', 3434),
#  ('thought', 3424),
#  ('network', 3417),
#  ('overal', 3394),
#  ('perform', 3393),
#  ('contact', 3387),
#  ('color', 3382),
#  ('hold', 3352),
#  ('hope', 3349),
#  ('refurbish', 3338),
#  ('data', 3336),
#  ('carrier', 3328),
#  ('messag', 3319),
#  ('low', 3317),
#  ('wo', 3317),
#  ('user', 3314),
#  ('lock', 3303),
#  ('version', 3301),
#  ('second', 3296),
#  ('support', 3273),
#  ('headphon', 3273),
#  ('de', 3269),
#  ('slow', 3260),
#  ('chang', 3259),
#  ('gift', 3259),
#  ('100', 3237),
#  ('fix', 3210),
#  ('softwar', 3193),
#  ('both', 3183),
#  ("'ll", 3164),
#  ('less', 3155),
#  ('sent', 3140),
#  ('1', 3124),
#  ('bluetooth', 3113),
#  ('found', 3107),
#  ('model', 3102),
#  ('satisfi', 3095),
#  ('person', 3092),
#  ('galaxi', 3084),
#  ('almost', 3081),
#  ('packag', 3079),
#  ('intern', 3078),
#  ('clear', 3059),
#  ('exactli', 3059),
#  ('yet', 3038),
#  ('may', 3035),
#  ('la', 3032),
#  ('hear', 3032),
#  ('complet', 3028),
#  ('wast', 3025),
#  ('super', 3010),
#  ('hand', 3009),
#  ('4g', 3002),
#  ('where', 2999),
#  ('googl', 2973),
#  ('home', 2973),
#  ('includ', 2966),
#  ('her', 2958),
#  ('origin', 2934),
#  ('alreadi', 2932),
#  ('number', 2925),
#  ('full', 2922),
#  ('storag', 2921),
#  ('until', 2899),
#  ('lo', 2883),
#  ('volum', 2882),
#  ('sometim', 2855),
#  ('game', 2853),
#  ('experi', 2850),
#  ('around', 2831),
#  ('itself', 2824),
#  ('display', 2816),
#  ('alway', 2799),
#  ('cost', 2793),
#  ('daughter', 2786),
#  ('que', 2780),
#  ('internet', 2777),
#  ('whi', 2766),
#  ('onc', 2737),
#  ('compar', 2725),
#  ('beauti', 2707),
#  ('en', 2694),
#  ('friend', 2688),
#  ('email', 2679),
#  ('lte', 2679),
#  ('complaint', 2642),
#  ('let', 2634),
#  ('cover', 2632),
#  ('warranti', 2630),
#  ('basic', 2623),
#  ('quit', 2602),
#  ('con', 2599),
#  ('mobil', 2573),
#  ('us', 2571),
#  ('anyon', 2564),
#  ('son', 2560),
#  ('front', 2536),
#  ('such', 2529),
#  ('fit', 2524),
#  ('photo', 2522),
#  ('told', 2519),
#  ('coupl', 2519),
#  ('option', 2515),
#  ('keyboard', 2505),
#  ('absolut', 2504),
#  ('plan', 2496),
#  ('respons', 2493),
#  ('quickli', 2482),
#  ('provid', 2465),
#  ('notic', 2450),
#  ('wish', 2446),
#  ('tell', 2446),
#  ('note', 2441),
#  ('quick', 2432),
#  ('show', 2425),
#  ('protector', 2397),
#  ('high', 2395),
#  ('away', 2355),
#  ('minut', 2354),
#  ('wait', 2350),
#  ('speed', 2337),
#  ('oper', 2336),
#  ('damag', 2328),
#  ('3g', 2297),
#  ('sever', 2293),
#  ('paid', 2291),
#  ('hi', 2282),
#  ('refund', 2281),
#  ('muy', 2278),
#  ('those', 2259),
#  ('venezuela', 2257),
#  ('check', 2254),
#  ('slot', 2250),
#  ('system', 2247),
#  ('type', 2246),
#  ('switch', 2246),
#  ('sprint', 2241),
#  ('part', 2241),
#  ('descript', 2240),
#  ('decent', 2230),
#  ('die', 2227),
#  ('impress', 2226),
#  ('wrong', 2210),
#  ('ago', 2203),
#  ('save', 2198),
#  ("'re", 2194),
#  ('ask', 2191),
#  ('wife', 2187),
#  ('band', 2167),
#  ('point', 2154),
#  ('os', 2150),
#  ('someon', 2145),
#  ('design', 2144),
#  ('window', 2138),
#  ('next', 2133),
#  ('freez', 2127),
#  ('black', 2126),
#  ('decid', 2121),
#  ('extrem', 2109),
#  ('live', 2109),
#  ("'d", 2090),
#  ('easili', 2074),
#  ('els', 2069),
#  ('miss', 2063),
#  ('gave', 2062),
#  ('except', 2061),
#  ('side', 2057),
#  ('defect', 2055),
#  ('10', 2048),
#  ('7', 2046),
#  ('although', 2042),
#  ('bright', 2042),
#  ('cellphon', 2041),
#  ('total', 2036),
#  ('place', 2028),
#  ('top', 2018),
#  ('within', 2015),
#  ('ram', 2010),
#  ('deliveri', 2008),
#  ('valu', 2008),
#  ('highli', 2007),
#  ('wonder', 2007),
#  ('plug', 1992),
#  ('8', 1991),
#  ('longer', 1989),
#  ('extra', 1976),
#  ('figur', 1966),
#  ('etc', 1965),
#  ('avail', 1952),
#  ('poor', 1949),
#  ('mean', 1947),
#  ('simpl', 1941),
#  ('straight', 1934),
#  ('manual', 1923),
#  ('state', 1922),
#  ('happen', 1919),
#  ('either', 1917),
#  ('expens', 1902),
#  ('remov', 1895),
#  ('gb', 1876),
#  ('care', 1874),
#  ('dual', 1868),
#  ('enjoy', 1867),
#  ('especi', 1859),
#  ('instead', 1846),
#  ('final', 1836),
#  ('broke', 1836),
#  ('three', 1836),
#  ('spend', 1828),
#  ('might', 1821),
#  ('cool', 1819),
#  ('crack', 1817),
#  ('probabl', 1811),
#  ('reset', 1811),
#  ('signal', 1806),
#  ('must', 1796),
#  ('micro', 1785),
#  ('dont', 1785),
#  ('factori', 1785),
#  ('half', 1785),
#  ('larg', 1781),
#  ('mayb', 1781),
#  ('cabl', 1778),
#  ('under', 1774),
#  ('suck', 1756),
#  ('properli', 1746),
#  ('fact', 1744),
#  ('later', 1728),
#  ('allow', 1726),
#  ('rate', 1721),
#  ('face', 1709),
#  ('stay', 1707),
#  ('horribl', 1706),
#  ('deliv', 1704),
#  ('producto', 1700),
#  ('suppos', 1700),
#  ('mine', 1700),
#  ('terribl', 1696),
#  ('usb', 1693),
#  ('least', 1686),
#  ('consid', 1686),
#  ('done', 1686),
#  ('es', 1682),
#  ('broken', 1681),
#  ('our', 1675),
#  ('u', 1660),
#  ('load', 1657),
#  ('accessori', 1654),
#  ('job', 1652),
#  ("'", 1650),
#  ('gsm', 1648),
#  ('shut', 1644),
#  ('list', 1642),
#  ('due', 1639),
#  ('loud', 1633),
#  ('today', 1631),
#  ('free', 1630),
#  ('surpris', 1627),
#  ('lag', 1625),
#  ('real', 1625),
#  ('studio', 1615),
#  ('5s', 1610),
#  ('ye', 1607),
#  ('goe', 1606),
#  ('kind', 1599),
#  ('huge', 1583),
#  ('blue', 1583),
#  ('30', 1574),
#  ('appear', 1571),
#  ('..', 1566),
#  ('onlin', 1564),
#  ('’', 1561),
#  ('test', 1558),
#  ('compat', 1557),
#  ('line', 1555),
#  ('glass', 1551),
#  ('notif', 1546),
#  ('worst', 1546),
#  ('guess', 1541),
#  ('cant', 1540),
#  ('previou', 1532),
#  ('piec', 1529),
#  ('offer', 1527),
#  ('left', 1523),
#  ('instruct', 1522),
#  ('im', 1520),
#  ('normal', 1494),
#  ('att', 1493),
#  ('unless', 1489),
#  ('answer', 1486),
#  ('inform', 1483),
#  ('pocket', 1475),
#  ('lost', 1466),
#  ('move', 1466),
#  ('sell', 1460),
#  ('faster', 1459),
#  ('repair', 1452),
#  ('caus', 1446),
#  ('close', 1443),
#  ('short', 1437),
#  ('plastic', 1435),
#  ('husband', 1431),
#  ('travel', 1429),
#  ('space', 1428),
#  ('troubl', 1427),
#  ('soon', 1421),
#  ('believ', 1418),
#  ('s', 1418),
#  ('white', 1409),
#  ('heavi', 1402),
#  ('key', 1398),
#  ('learn', 1388),
#  ('resolut', 1385),
#  ('flash', 1385),
#  ('gp', 1384),
#  ('audio', 1379),
#  ('gener', 1379),
#  ('protect', 1379),
#  ('voic', 1370),
#  ('unfortun', 1369),
#  ('bb', 1364),
#  ('spec', 1363),
#  ('asu', 1359),
#  ('otherwis', 1358),
#  ('account', 1355),
#  ('write', 1353),
#  ('processor', 1351),
#  ('countri', 1347),
#  ('4s', 1345),
#  ('complain', 1337),
#  ('solid', 1337),
#  ('access', 1336),
#  ('huawei', 1334),
#  ('tech', 1315),
#  ('dollar', 1314),
#  ('sold', 1305),
#  ('mention', 1305),
#  ('bigger', 1299),
#  ('promis', 1295),
#  ('glad', 1293),
#  ('port', 1292),
#  ('market', 1292),
#  ('fulli', 1292),
#  ('restart', 1292),
#  ('beat', 1287),
#  ('search', 1286),
#  ('hd', 1284),
#  ('ad', 1282),
#  ('useless', 1274),
#  ('name', 1270),
#  ('fantast', 1268),
#  ('wireless', 1260),
#  ('okay', 1257),
#  ('busi', 1252),
#  ('between', 1249),
#  ('difficult', 1247),
#  ('mode', 1236),
#  ('press', 1233),
#  ('date', 1232),
#  ('whole', 1229),
#  ('often', 1227),
#  ('myself', 1226),
#  ('io', 1226),
#  ('simpli', 1223),
#  ('guy', 1222),
#  ('bueno', 1220),
#  ('add', 1219),
#  ('unit', 1216),
#  ('annoy', 1214),
#  ('respond', 1213),
#  ('nexu', 1213),
#  ('minor', 1206),
#  ('dead', 1199),
#  ('smooth', 1198),
#  ('un', 1192),
#  ('kept', 1191),
#  ('se', 1186),
#  ('worri', 1186),
#  ('area', 1186),
#  ('past', 1184),
#  ('hate', 1184),
#  ('reboot', 1183),
#  ('web', 1180),
#  ('current', 1180),
#  ('understand', 1179),
#  ('bottom', 1177),
#  ('lack', 1175),
#  ('process', 1173),
#  ('usag', 1166),
#  ('radio', 1162),
#  ('recept', 1159),
#  ('sync', 1158),
#  ('contract', 1157),
#  ('fail', 1155),
#  ('afford', 1154),
#  ('him', 1154),
#  ('insid', 1153),
#  ('water', 1153),
#  ('ear', 1153),
#  ('given', 1149),
#  ('constantli', 1148),
#  ('listen', 1147),
#  ('stuff', 1143),
#  ('kid', 1140),
#  ('stock', 1140),
#  ('requir', 1136),
#  ('mind', 1136),
#  ('6s', 1132),
#  ('break', 1125),
#  ('build', 1119),
#  ('applic', 1117),
#  ('drain', 1116),
#  ('everyon', 1112),
#  ('major', 1112),
#  ('lollipop', 1110),
#  ('wear', 1106),
#  ('clean', 1105),
#  ('lg', 1104),
#  ('budget', 1103),
#  ('built', 1099),
#  ('night', 1099),
#  ('mom', 1097),
#  ('stuck', 1094),
#  ('por', 1091),
#  ('immedi', 1086),
#  ('pic', 1086),
#  ('chip', 1079),
#  ('pick', 1072),
#  ('control', 1072),
#  ('continu', 1072),
#  ('lose', 1067),
#  ('limit', 1066),
#  ('main', 1061),
#  ('famili', 1059),
#  ('insert', 1057),
#  ('spent', 1057),
#  ('glitch', 1051),
#  ('hot', 1050),
#  ('standard', 1045),
#  ('usual', 1044),
#  ('shape', 1043),
#  ('anyway', 1041),
#  ('matter', 1040),
#  ('20', 1038),
#  ('choic', 1032),
#  ('bien', 1032),
#  ('file', 1031),
#  ('x', 1031),
#  ('addit', 1023),
#  ('bare', 1015),
#  ('hardwar', 1015),
#  ('transfer', 1013),
#  ('accept', 1011),
#  ('program', 1011),
#  ('reliabl', 1006),
#  ('tablet', 1003),
#  ('capabl', 993),
#  ('seen', 987),
#  ('possibl', 977),
#  ('junk', 973),
#  ('dure', 970),
#  ('leav', 966),
#  ('finger', 963),
#  ('world', 962),
#  ('comput', 961),
#  ('christma', 961),
#  ('manufactur', 961),
#  ('200', 959),
#  ('crash', 958),
#  ('recent', 957),
#  ('5c', 956),
#  ('seal', 955),
#  ('edg', 954),
#  ('todo', 952),
#  ('inch', 952),
#  ('regret', 949),
#  ('research', 947),
#  ('realiz', 947),
#  ('manag', 946),
#  ('wi-fi', 945),
#  ('thin', 944),
#  ('50', 944),
#  ('youtub', 943),
#  ('rather', 941),
#  ('regular', 939),
#  ('question', 938),
#  ('import', 936),
#  ('frustrat', 935),
#  ('buck', 935),
#  ('stolen', 932),
#  ('telefono', 927),
#  ('larger', 926),
#  ('headset', 926),
#  ('para', 926),
#  ('smaller', 924),
#  ('car', 923),
#  ('unabl', 923),
#  ('imag', 923),
#  ('suggest', 920),
#  ('pair', 920),
#  ('fingerprint', 920),
#  ('tmobil', 914),
#  ('meet', 914),
#  ('facebook', 910),
#  ('outsid', 903),
#  ('rang', 902),
#  ('mail', 901),
#  ('each', 899),
#  ('menu', 898),
#  ('via', 894),
#  ('detail', 894),
#  ('handl', 893),
#  ('present', 891),
#  ('bring', 891),
#  ('adapt', 891),
#  ('local', 890),
#  ('pop', 890),
#  ('page', 884),
#  ('navig', 883),
#  ('launcher', 878),
#  ('carri', 875),
#  ('similar', 873),
#  ('wont', 869),
#  ('twice', 867),
#  ('mi', 864),
#  ('interfac', 861),
#  ('llego', 860),
#  ('chines', 860),
#  ('cut', 856),
#  ('post', 855),
#  ('cheaper', 851),
#  ('readi', 849),
#  ('recomiendo', 845),
#  ('didnt', 840),
#  ('5.0', 839),
#  ('doesnt', 836),
#  ('cours', 829),
#  ('ring', 826),
#  ('buen', 823),
#  ('specif', 823),
#  ('improv', 822),
#  ('neg', 821),
#  ('32gb', 821),
#  ('met', 819),
#  ('technolog', 819),
#  ('excit', 819),
#  ('c', 819),
#  ('pro', 814),
#  ('amount', 811),
#  ('gold', 810),
#  ('cellular', 809),
#  ('prefer', 809),
#  ('recogn', 806),
#  ('cord', 806),
#  ('multipl', 806),
#  ('futur', 805),
#  ('crap', 803),
#  ('base', 800),
#  ('mess', 798),
#  ('weight', 795),
#  ('languag', 790),
#  ('64gb', 786),
#  ('slightli', 781),
#  ('incred', 780),
#  ('third', 779),
#  ('older', 778),
#  ('honestli', 778),
#  ('earli', 778),
#  ('bar', 776),
#  ('brought', 775),
#  ('becom', 775),
#  ('hit', 774),
#  ('comfort', 774),
#  ('randomli', 772),
#  ('buyer', 771),
#  ('claim', 767),
#  ('>', 766),
#  ('root', 764),
#  ('initi', 763),
#  ('durabl', 759),
#  ('xl', 756),
#  ('wors', 755),
#  ('concern', 755),
#  ('view', 749),
#  ('fake', 748),
#  ('earlier', 746),
#  ('5.5', 742),
#  ('shop', 741),
#  ('delet', 741),
#  ('16gb', 741),
#  ('saw', 740),
#  ('fairli', 738),
#  ('fall', 738),
#  ('latest', 737),
#  ('player', 736),
#  ('vivo', 736),
#  ('est', 735),
#  ('equipo', 733),
#  ('15', 733),
#  ('vibrat', 730),
#  ('setup', 729),
#  ('dial', 728),
#  ('earphon', 728),
#  ('word', 727),
#  ('abov', 727),
#  ('pure', 727),
#  ('#', 726),
#  ('mini', 726),
#  ('bloatwar', 726),
#  ('singl', 724),
#  ('idea', 722),
#  ('record', 722),
#  ('flagship', 721),
#  ('error', 720),
#  ('code', 720),
#  ('releas', 718),
#  ('correct', 715),
#  ('/', 714),
#  ('comment', 713),
#  ('fan', 713),
#  ('websit', 713),
#  ('taken', 713),
#  ('five', 713),
#  ('true', 710),
#  ('stick', 709),
#  ('fun', 705),
#  ('jack', 698),
#  ('opinion', 697),
#  ('12', 696),
#  ('report', 695),
#  ('browser', 693),
#  ('.i', 693),
#  ('gotten', 692),
#  ('push', 692),
#  ('higher', 691),
#  ('locat', 689),
#  ('sensor', 687),
#  ('english', 685),
#  ('loos', 683),
#  ('backup', 683),
#  ('easier', 681),
#  ('anymor', 680),
#  ('four', 679),
#  ('s4', 677),
#  ('step', 666),
#  ('birthday', 664),
#  ('posit', 663),
#  ('commun', 663),
#  ('chanc', 662),
#  ('averag', 661),
#  ('pc', 660),
#  ('cricket', 656),
#  ('anywher', 655),
#  ('earbud', 654),
#  ('pull', 652),
#  ('g', 652),
#  ('choos', 651),
#  ('honor', 649),
#  ('brows', 648),
#  ('automat', 648),
#  ('tap', 648),
#  ('stream', 648),
#  ('level', 646),
#  ('media', 645),
#  ('vendedor', 645),
#  ('click', 643),
#  ('lol', 643),
#  ('ok.', 643),
#  ('fault', 643),
#  ('wall', 643),
#  ('gracia', 642),
#  ('physic', 642),
#  ('clearli', 642),
#  ('plenti', 641),
#  ('vendor', 640),
#  ('besid', 640),
#  ('head', 640),
#  ('una', 639),
#  ('truli', 639),
#  ('select', 638),
#  ('purpos', 638),
#  ('map', 636),
#  ('secur', 635),
#  ...]

# %%
punctuation_marks = [".", ",", "(", ")", "?", "[", "]", "-", "_", "--", "''", ":", ";", "&", "``", "...", "%" ]
stopwords = ["a", "about", "after", "all", "am", "an", "and", "any", "are", "as", "at", "be", "because", "been",
            "before", "being", "between", "both", "by", "could", "did", "do", "does", "doing", "during", "each",
            "for", "from", "further", "had", "has", "have", "having", "he", "her", "here", "hers", "herself", "him",
            "himself", "his", "how", "i", "in", "into", "is", "it", "its", "itself", "let", "me", "more", "most", "my",
            "myself", "of", "on", "once", "only", "or", "other", "ought", "our", "ours", "ourselves", "own", "sha",
            "she", "should", "so", "some", "such", "than", "that", "the", "their", "theirs", "them", "themselves",
            "then", "there", "there's", "these", "they", "this", "those", "through", "to", "until", "up", "very",
            "was", "we", "were", "what", "when", "where", "which", "while", "who","whom", "with", "would", "you",
            "your", "yours", "yourself", "yourselves",
            "n't", "'s", "'ll", "'re", "'d", "'m", "'ve",
            "above", "again", "against", "below", "but",  "few", "if",  "off",
            "out", "over", "same", "too", "under", "why"]
# "no", "nor", "not","cannot", "down",

# %%
for p in punctuation_marks:
    if (words[p] > 0):
        del words[p]
        
# for s in stopwords:
#     if (words[s] > 0):
#         del words[s]

# %%
words.most_common()
# Out:
# [('the', 337576),
#  ('i', 261670),
#  ('it', 249429),
#  ('phone', 201344),
#  ('and', 199329),
#  ('a', 178419),
#  ('to', 172959),
#  ('is', 136464),
#  ('thi', 105022),
#  ('for', 94337),
#  ('!', 87733),
#  ('wa', 79360),
#  ('not', 78951),
#  ('with', 76175),
#  ('my', 75552),
#  ('of', 72734),
#  ('in', 67759),
#  ('that', 65872),
#  ('but', 63489),
#  ('work', 59462),
#  ('on', 58620),
#  ("n't", 55743),
#  ('have', 55429),
#  ('you', 51284),
#  ('great', 47260),
#  ('good', 47014),
#  ('use', 44314),
#  ('as', 43843),
#  ('veri', 42679),
#  ('so', 39681),
#  ("'s", 35530),
#  ('be', 33063),
#  ('had', 31573),
#  ('no', 30453),
#  ('like', 30092),
#  ('do', 30018),
#  ('one', 28659),
#  ('all', 28207),
#  ('get', 27301),
#  ('love', 27256),
#  ('screen', 26600),
#  ('at', 26476),
#  ('me', 26324),
#  ('just', 25285),
#  ('would', 24439),
#  ('batteri', 23981),
#  ('or', 23697),
#  ('from', 23405),
#  ('if', 23160),
#  ('can', 22928),
#  ('an', 22846),
#  ('ha', 22801),
#  ('new', 22503),
#  ('are', 22469),
#  ('when', 21164),
#  ('time', 20760),
#  ('iphon', 20474),
#  ('will', 20356),
#  ('onli', 20309),
#  ('doe', 19973),
#  ('price', 19333),
#  ('product', 19073),
#  ('did', 18725),
#  ('buy', 18631),
#  ('they', 18297),
#  ('up', 17596),
#  ('out', 16750),
#  ('than', 16469),
#  ('look', 16368),
#  ('realli', 16122),
#  ('app', 16083),
#  ('card', 15939),
#  ('problem', 15828),
#  ('about', 15739),
#  ('sim', 15700),
#  ('excel', 15247),
#  ('day', 15207),
#  ('bought', 15173),
#  ('camera', 15114),
#  ('what', 14968),
#  ('got', 14638),
#  ('am', 14630),
#  ('well', 14317),
#  ('becaus', 14267),
#  ('after', 14240),
#  ('purchas', 13807),
#  ('other', 13801),
#  ('even', 13662),
#  ('more', 13587),
#  ('there', 13557),
#  ("'m", 13500),
#  ('charg', 13166),
#  ('back', 13010),
#  ('need', 12995),
#  ('now', 12774),
#  ('could', 12682),
#  ('nice', 12649),
#  ('blu', 12518),
#  ('call', 12401),
#  ('came', 11863),
#  ('watch', 11630),
#  ('want', 11612),
#  ('which', 11576),
#  ('unlock', 11414),
#  ('ani', 11221),
#  ('also', 10992),
#  ('go', 10944),
#  ('qualiti', 10883),
#  ('expect', 10878),
#  ('your', 10874),
#  ('month', 10860),
#  ('much', 10699),
#  ('fast', 10514),
#  ('receiv', 10491),
#  ('some', 10481),
#  ('recommend', 10281),
#  ('better', 10105),
#  ('$', 10075),
#  ('been', 10037),
#  ('still', 9907),
#  ('everyth', 9737),
#  ('thing', 9600),
#  ('make', 9536),
#  ('return', 9460),
#  ('perfect', 9403),
#  ('issu', 9380),
#  ('take', 9338),
#  ('say', 9290),
#  ('by', 9208),
#  ('tri', 9185),
#  ('first', 9155),
#  ('off', 8942),
#  ('life', 8940),
#  ('then', 8921),
#  ('come', 8893),
#  ('seller', 8858),
#  ('2', 8857),
#  ("'ve", 8776),
#  ('devic', 8638),
#  ('far', 8585),
#  ('android', 8556),
#  ('thank', 8517),
#  ('money', 8413),
#  ('appl', 8394),
#  ('happi', 8282),
#  ('condit', 8057),
#  ('we', 7962),
#  ('too', 7946),
#  ('servic', 7930),
#  ('case', 7898),
#  ('ca', 7857),
#  ('turn', 7751),
#  ('them', 7702),
#  ('amazon', 7604),
#  ('charger', 7444),
#  ('littl', 7338),
#  ('order', 7322),
#  ('best', 7310),
#  ('set', 7307),
#  ('last', 7270),
#  ('fine', 7146),
#  ('brand', 7064),
#  ('never', 6972),
#  ('replac', 6919),
#  ('review', 6917),
#  ('lot', 6865),
#  ('week', 6859),
#  ('how', 6834),
#  ('featur', 6778),
#  ('bad', 6724),
#  ('few', 6707),
#  ('two', 6687),
#  ('know', 6644),
#  ('again', 6536),
#  ('updat', 6375),
#  ('easi', 6368),
#  ('anoth', 6339),
#  ('5', 6282),
#  ('were', 6220),
#  ('t', 6217),
#  ('over', 6206),
#  ('seem', 6117),
#  ('big', 6097),
#  ('he', 6039),
#  ('way', 6034),
#  ('pictur', 6027),
#  ('year', 5917),
#  ('box', 5909),
#  ('think', 5878),
#  ('3', 5876),
#  ('sinc', 5869),
#  ('without', 5839),
#  ('arriv', 5811),
#  ('text', 5704),
#  ('connect', 5660),
#  ('same', 5602),
#  ('befor', 5579),
#  ('pretti', 5523),
#  ('button', 5497),
#  ('give', 5475),
#  ('speaker', 5433),
#  ('she', 5428),
#  ('said', 5390),
#  ('see', 5388),
#  ('start', 5373),
#  ('item', 5365),
#  ('right', 5319),
#  ('old', 5268),
#  ('run', 5263),
#  ('amaz', 5215),
#  ('ship', 5206),
#  ('find', 5187),
#  ('feel', 5175),
#  ('cell', 5166),
#  ('activ', 5129),
#  ('blackberri', 5083),
#  ('awesom', 5057),
#  ('abl', 5024),
#  ('4', 5011),
#  ('scratch', 4985),
#  ('while', 4978),
#  ('ever', 4977),
#  ('howev', 4928),
#  ('ok', 4917),
#  ('keep', 4900),
#  ('disappoint', 4899),
#  ('put', 4888),
#  ('though', 4873),
#  ('star', 4815),
#  ('sound', 4809),
#  ('should', 4753),
#  ('samsung', 4737),
#  ('size', 4733),
#  ('their', 4720),
#  ('pleas', 4689),
#  ('function', 4674),
#  ('send', 4654),
#  ('most', 4639),
#  ('play', 4551),
#  ('excelent', 4538),
#  ('store', 4530),
#  ('mani', 4512),
#  ('memori', 4475),
#  ('hour', 4416),
#  ('differ', 4402),
#  ('took', 4394),
#  ('long', 4372),
#  ('sure', 4353),
#  ('custom', 4351),
#  ('who', 4315),
#  ('describ', 4275),
#  ('6', 4227),
#  ('down', 4220),
#  ('stop', 4171),
#  ('perfectli', 4169),
#  ('pay', 4141),
#  ('verizon', 4096),
#  ('touch', 4080),
#  ('these', 4067),
#  ('video', 4058),
#  ('everi', 4033),
#  ('el', 3996),
#  ('peopl', 3961),
#  ('made', 3957),
#  ('plu', 3955),
#  ('read', 3943),
#  ('power', 3941),
#  ('help', 3928),
#  ('deal', 3922),
#  ('sd', 3871),
#  ('went', 3869),
#  ('y', 3862),
#  ('compani', 3813),
#  ('enough', 3792),
#  ('own', 3781),
#  ('someth', 3774),
#  ('into', 3762),
#  ('smartphon', 3746),
#  ('worth', 3739),
#  ('cheap', 3737),
#  ('here', 3720),
#  ('bit', 3718),
#  ('talk', 3717),
#  ('open', 3713),
#  ('definit', 3656),
#  ('htc', 3650),
#  ('upgrad', 3638),
#  ('actual', 3621),
#  ('small', 3612),
#  ('noth', 3612),
#  ('smart', 3598),
#  ('through', 3581),
#  ('reason', 3557),
#  ('t-mobil', 3512),
#  ('wifi', 3507),
#  ('hard', 3500),
#  ('end', 3497),
#  ('music', 3481),
#  ('drop', 3459),
#  ('advertis', 3448),
#  ('download', 3438),
#  ('instal', 3435),
#  ('anyth', 3435),
#  ('light', 3434),
#  ('thought', 3424),
#  ('network', 3417),
#  ('overal', 3394),
#  ('perform', 3393),
#  ('contact', 3387),
#  ('color', 3382),
#  ('hold', 3352),
#  ('hope', 3349),
#  ('refurbish', 3338),
#  ('data', 3336),
#  ('carrier', 3328),
#  ('messag', 3319),
#  ('low', 3317),
#  ('wo', 3317),
#  ('user', 3314),
#  ('lock', 3303),
#  ('version', 3301),
#  ('second', 3296),
#  ('support', 3273),
#  ('headphon', 3273),
#  ('de', 3269),
#  ('slow', 3260),
#  ('chang', 3259),
#  ('gift', 3259),
#  ('100', 3237),
#  ('fix', 3210),
#  ('softwar', 3193),
#  ('both', 3183),
#  ("'ll", 3164),
#  ('less', 3155),
#  ('sent', 3140),
#  ('1', 3124),
#  ('bluetooth', 3113),
#  ('found', 3107),
#  ('model', 3102),
#  ('satisfi', 3095),
#  ('person', 3092),
#  ('galaxi', 3084),
#  ('almost', 3081),
#  ('packag', 3079),
#  ('intern', 3078),
#  ('clear', 3059),
#  ('exactli', 3059),
#  ('yet', 3038),
#  ('may', 3035),
#  ('la', 3032),
#  ('hear', 3032),
#  ('complet', 3028),
#  ('wast', 3025),
#  ('super', 3010),
#  ('hand', 3009),
#  ('4g', 3002),
#  ('where', 2999),
#  ('googl', 2973),
#  ('home', 2973),
#  ('includ', 2966),
#  ('her', 2958),
#  ('origin', 2934),
#  ('alreadi', 2932),
#  ('number', 2925),
#  ('full', 2922),
#  ('storag', 2921),
#  ('until', 2899),
#  ('lo', 2883),
#  ('volum', 2882),
#  ('sometim', 2855),
#  ('game', 2853),
#  ('experi', 2850),
#  ('around', 2831),
#  ('itself', 2824),
#  ('display', 2816),
#  ('alway', 2799),
#  ('cost', 2793),
#  ('daughter', 2786),
#  ('que', 2780),
#  ('internet', 2777),
#  ('whi', 2766),
#  ('onc', 2737),
#  ('compar', 2725),
#  ('beauti', 2707),
#  ('en', 2694),
#  ('friend', 2688),
#  ('email', 2679),
#  ('lte', 2679),
#  ('complaint', 2642),
#  ('let', 2634),
#  ('cover', 2632),
#  ('warranti', 2630),
#  ('basic', 2623),
#  ('quit', 2602),
#  ('con', 2599),
#  ('mobil', 2573),
#  ('us', 2571),
#  ('anyon', 2564),
#  ('son', 2560),
#  ('front', 2536),
#  ('such', 2529),
#  ('fit', 2524),
#  ('photo', 2522),
#  ('told', 2519),
#  ('coupl', 2519),
#  ('option', 2515),
#  ('keyboard', 2505),
#  ('absolut', 2504),
#  ('plan', 2496),
#  ('respons', 2493),
#  ('quickli', 2482),
#  ('provid', 2465),
#  ('notic', 2450),
#  ('wish', 2446),
#  ('tell', 2446),
#  ('note', 2441),
#  ('quick', 2432),
#  ('show', 2425),
#  ('protector', 2397),
#  ('high', 2395),
#  ('away', 2355),
#  ('minut', 2354),
#  ('wait', 2350),
#  ('speed', 2337),
#  ('oper', 2336),
#  ('damag', 2328),
#  ('3g', 2297),
#  ('sever', 2293),
#  ('paid', 2291),
#  ('hi', 2282),
#  ('refund', 2281),
#  ('muy', 2278),
#  ('those', 2259),
#  ('venezuela', 2257),
#  ('check', 2254),
#  ('slot', 2250),
#  ('system', 2247),
#  ('type', 2246),
#  ('switch', 2246),
#  ('sprint', 2241),
#  ('part', 2241),
#  ('descript', 2240),
#  ('decent', 2230),
#  ('die', 2227),
#  ('impress', 2226),
#  ('wrong', 2210),
#  ('ago', 2203),
#  ('save', 2198),
#  ("'re", 2194),
#  ('ask', 2191),
#  ('wife', 2187),
#  ('band', 2167),
#  ('point', 2154),
#  ('os', 2150),
#  ('someon', 2145),
#  ('design', 2144),
#  ('window', 2138),
#  ('next', 2133),
#  ('freez', 2127),
#  ('black', 2126),
#  ('decid', 2121),
#  ('extrem', 2109),
#  ('live', 2109),
#  ("'d", 2090),
#  ('easili', 2074),
#  ('els', 2069),
#  ('miss', 2063),
#  ('gave', 2062),
#  ('except', 2061),
#  ('side', 2057),
#  ('defect', 2055),
#  ('10', 2048),
#  ('7', 2046),
#  ('although', 2042),
#  ('bright', 2042),
#  ('cellphon', 2041),
#  ('total', 2036),
#  ('place', 2028),
#  ('top', 2018),
#  ('within', 2015),
#  ('ram', 2010),
#  ('deliveri', 2008),
#  ('valu', 2008),
#  ('highli', 2007),
#  ('wonder', 2007),
#  ('plug', 1992),
#  ('8', 1991),
#  ('longer', 1989),
#  ('extra', 1976),
#  ('figur', 1966),
#  ('etc', 1965),
#  ('avail', 1952),
#  ('poor', 1949),
#  ('mean', 1947),
#  ('simpl', 1941),
#  ('straight', 1934),
#  ('manual', 1923),
#  ('state', 1922),
#  ('happen', 1919),
#  ('either', 1917),
#  ('expens', 1902),
#  ('remov', 1895),
#  ('gb', 1876),
#  ('care', 1874),
#  ('dual', 1868),
#  ('enjoy', 1867),
#  ('especi', 1859),
#  ('instead', 1846),
#  ('final', 1836),
#  ('broke', 1836),
#  ('three', 1836),
#  ('spend', 1828),
#  ('might', 1821),
#  ('cool', 1819),
#  ('crack', 1817),
#  ('probabl', 1811),
#  ('reset', 1811),
#  ('signal', 1806),
#  ('must', 1796),
#  ('micro', 1785),
#  ('dont', 1785),
#  ('factori', 1785),
#  ('half', 1785),
#  ('larg', 1781),
#  ('mayb', 1781),
#  ('cabl', 1778),
#  ('under', 1774),
#  ('suck', 1756),
#  ('properli', 1746),
#  ('fact', 1744),
#  ('later', 1728),
#  ('allow', 1726),
#  ('rate', 1721),
#  ('face', 1709),
#  ('stay', 1707),
#  ('horribl', 1706),
#  ('deliv', 1704),
#  ('producto', 1700),
#  ('suppos', 1700),
#  ('mine', 1700),
#  ('terribl', 1696),
#  ('usb', 1693),
#  ('least', 1686),
#  ('consid', 1686),
#  ('done', 1686),
#  ('es', 1682),
#  ('broken', 1681),
#  ('our', 1675),
#  ('u', 1660),
#  ('load', 1657),
#  ('accessori', 1654),
#  ('job', 1652),
#  ("'", 1650),
#  ('gsm', 1648),
#  ('shut', 1644),
#  ('list', 1642),
#  ('due', 1639),
#  ('loud', 1633),
#  ('today', 1631),
#  ('free', 1630),
#  ('surpris', 1627),
#  ('lag', 1625),
#  ('real', 1625),
#  ('studio', 1615),
#  ('5s', 1610),
#  ('ye', 1607),
#  ('goe', 1606),
#  ('kind', 1599),
#  ('huge', 1583),
#  ('blue', 1583),
#  ('30', 1574),
#  ('appear', 1571),
#  ('..', 1566),
#  ('onlin', 1564),
#  ('’', 1561),
#  ('test', 1558),
#  ('compat', 1557),
#  ('line', 1555),
#  ('glass', 1551),
#  ('notif', 1546),
#  ('worst', 1546),
#  ('guess', 1541),
#  ('cant', 1540),
#  ('previou', 1532),
#  ('piec', 1529),
#  ('offer', 1527),
#  ('left', 1523),
#  ('instruct', 1522),
#  ('im', 1520),
#  ('normal', 1494),
#  ('att', 1493),
#  ('unless', 1489),
#  ('answer', 1486),
#  ('inform', 1483),
#  ('pocket', 1475),
#  ('lost', 1466),
#  ('move', 1466),
#  ('sell', 1460),
#  ('faster', 1459),
#  ('repair', 1452),
#  ('caus', 1446),
#  ('close', 1443),
#  ('short', 1437),
#  ('plastic', 1435),
#  ('husband', 1431),
#  ('travel', 1429),
#  ('space', 1428),
#  ('troubl', 1427),
#  ('soon', 1421),
#  ('believ', 1418),
#  ('s', 1418),
#  ('white', 1409),
#  ('heavi', 1402),
#  ('key', 1398),
#  ('learn', 1388),
#  ('resolut', 1385),
#  ('flash', 1385),
#  ('gp', 1384),
#  ('audio', 1379),
#  ('gener', 1379),
#  ('protect', 1379),
#  ('voic', 1370),
#  ('unfortun', 1369),
#  ('bb', 1364),
#  ('spec', 1363),
#  ('asu', 1359),
#  ('otherwis', 1358),
#  ('account', 1355),
#  ('write', 1353),
#  ('processor', 1351),
#  ('countri', 1347),
#  ('4s', 1345),
#  ('complain', 1337),
#  ('solid', 1337),
#  ('access', 1336),
#  ('huawei', 1334),
#  ('tech', 1315),
#  ('dollar', 1314),
#  ('sold', 1305),
#  ('mention', 1305),
#  ('bigger', 1299),
#  ('promis', 1295),
#  ('glad', 1293),
#  ('port', 1292),
#  ('market', 1292),
#  ('fulli', 1292),
#  ('restart', 1292),
#  ('beat', 1287),
#  ('search', 1286),
#  ('hd', 1284),
#  ('ad', 1282),
#  ('useless', 1274),
#  ('name', 1270),
#  ('fantast', 1268),
#  ('wireless', 1260),
#  ('okay', 1257),
#  ('busi', 1252),
#  ('between', 1249),
#  ('difficult', 1247),
#  ('mode', 1236),
#  ('press', 1233),
#  ('date', 1232),
#  ('whole', 1229),
#  ('often', 1227),
#  ('myself', 1226),
#  ('io', 1226),
#  ('simpli', 1223),
#  ('guy', 1222),
#  ('bueno', 1220),
#  ('add', 1219),
#  ('unit', 1216),
#  ('annoy', 1214),
#  ('respond', 1213),
#  ('nexu', 1213),
#  ('minor', 1206),
#  ('dead', 1199),
#  ('smooth', 1198),
#  ('un', 1192),
#  ('kept', 1191),
#  ('se', 1186),
#  ('worri', 1186),
#  ('area', 1186),
#  ('past', 1184),
#  ('hate', 1184),
#  ('reboot', 1183),
#  ('web', 1180),
#  ('current', 1180),
#  ('understand', 1179),
#  ('bottom', 1177),
#  ('lack', 1175),
#  ('process', 1173),
#  ('usag', 1166),
#  ('radio', 1162),
#  ('recept', 1159),
#  ('sync', 1158),
#  ('contract', 1157),
#  ('fail', 1155),
#  ('afford', 1154),
#  ('him', 1154),
#  ('insid', 1153),
#  ('water', 1153),
#  ('ear', 1153),
#  ('given', 1149),
#  ('constantli', 1148),
#  ('listen', 1147),
#  ('stuff', 1143),
#  ('kid', 1140),
#  ('stock', 1140),
#  ('requir', 1136),
#  ('mind', 1136),
#  ('6s', 1132),
#  ('break', 1125),
#  ('build', 1119),
#  ('applic', 1117),
#  ('drain', 1116),
#  ('everyon', 1112),
#  ('major', 1112),
#  ('lollipop', 1110),
#  ('wear', 1106),
#  ('clean', 1105),
#  ('lg', 1104),
#  ('budget', 1103),
#  ('built', 1099),
#  ('night', 1099),
#  ('mom', 1097),
#  ('stuck', 1094),
#  ('por', 1091),
#  ('immedi', 1086),
#  ('pic', 1086),
#  ('chip', 1079),
#  ('pick', 1072),
#  ('control', 1072),
#  ('continu', 1072),
#  ('lose', 1067),
#  ('limit', 1066),
#  ('main', 1061),
#  ('famili', 1059),
#  ('insert', 1057),
#  ('spent', 1057),
#  ('glitch', 1051),
#  ('hot', 1050),
#  ('standard', 1045),
#  ('usual', 1044),
#  ('shape', 1043),
#  ('anyway', 1041),
#  ('matter', 1040),
#  ('20', 1038),
#  ('choic', 1032),
#  ('bien', 1032),
#  ('file', 1031),
#  ('x', 1031),
#  ('addit', 1023),
#  ('bare', 1015),
#  ('hardwar', 1015),
#  ('transfer', 1013),
#  ('accept', 1011),
#  ('program', 1011),
#  ('reliabl', 1006),
#  ('tablet', 1003),
#  ('capabl', 993),
#  ('seen', 987),
#  ('possibl', 977),
#  ('junk', 973),
#  ('dure', 970),
#  ('leav', 966),
#  ('finger', 963),
#  ('world', 962),
#  ('comput', 961),
#  ('christma', 961),
#  ('manufactur', 961),
#  ('200', 959),
#  ('crash', 958),
#  ('recent', 957),
#  ('5c', 956),
#  ('seal', 955),
#  ('edg', 954),
#  ('todo', 952),
#  ('inch', 952),
#  ('regret', 949),
#  ('research', 947),
#  ('realiz', 947),
#  ('manag', 946),
#  ('wi-fi', 945),
#  ('thin', 944),
#  ('50', 944),
#  ('youtub', 943),
#  ('rather', 941),
#  ('regular', 939),
#  ('question', 938),
#  ('import', 936),
#  ('frustrat', 935),
#  ('buck', 935),
#  ('stolen', 932),
#  ('telefono', 927),
#  ('larger', 926),
#  ('headset', 926),
#  ('para', 926),
#  ('smaller', 924),
#  ('car', 923),
#  ('unabl', 923),
#  ('imag', 923),
#  ('suggest', 920),
#  ('pair', 920),
#  ('fingerprint', 920),
#  ('tmobil', 914),
#  ('meet', 914),
#  ('facebook', 910),
#  ('outsid', 903),
#  ('rang', 902),
#  ('mail', 901),
#  ('each', 899),
#  ('menu', 898),
#  ('via', 894),
#  ('detail', 894),
#  ('handl', 893),
#  ('present', 891),
#  ('bring', 891),
#  ('adapt', 891),
#  ('local', 890),
#  ('pop', 890),
#  ('page', 884),
#  ('navig', 883),
#  ('launcher', 878),
#  ('carri', 875),
#  ('similar', 873),
#  ('wont', 869),
#  ('twice', 867),
#  ('mi', 864),
#  ('interfac', 861),
#  ('llego', 860),
#  ('chines', 860),
#  ('cut', 856),
#  ('post', 855),
#  ('cheaper', 851),
#  ('readi', 849),
#  ('recomiendo', 845),
#  ('didnt', 840),
#  ('5.0', 839),
#  ('doesnt', 836),
#  ('cours', 829),
#  ('ring', 826),
#  ('buen', 823),
#  ('specif', 823),
#  ('improv', 822),
#  ('neg', 821),
#  ('32gb', 821),
#  ('met', 819),
#  ('technolog', 819),
#  ('excit', 819),
#  ('c', 819),
#  ('pro', 814),
#  ('amount', 811),
#  ('gold', 810),
#  ('cellular', 809),
#  ('prefer', 809),
#  ('recogn', 806),
#  ('cord', 806),
#  ('multipl', 806),
#  ('futur', 805),
#  ('crap', 803),
#  ('base', 800),
#  ('mess', 798),
#  ('weight', 795),
#  ('languag', 790),
#  ('64gb', 786),
#  ('slightli', 781),
#  ('incred', 780),
#  ('third', 779),
#  ('older', 778),
#  ('honestli', 778),
#  ('earli', 778),
#  ('bar', 776),
#  ('brought', 775),
#  ('becom', 775),
#  ('hit', 774),
#  ('comfort', 774),
#  ('randomli', 772),
#  ('buyer', 771),
#  ('claim', 767),
#  ('>', 766),
#  ('root', 764),
#  ('initi', 763),
#  ('durabl', 759),
#  ('xl', 756),
#  ('wors', 755),
#  ('concern', 755),
#  ('view', 749),
#  ('fake', 748),
#  ('earlier', 746),
#  ('5.5', 742),
#  ('shop', 741),
#  ('delet', 741),
#  ('16gb', 741),
#  ('saw', 740),
#  ('fairli', 738),
#  ('fall', 738),
#  ('latest', 737),
#  ('player', 736),
#  ('vivo', 736),
#  ('est', 735),
#  ('equipo', 733),
#  ('15', 733),
#  ('vibrat', 730),
#  ('setup', 729),
#  ('dial', 728),
#  ('earphon', 728),
#  ('word', 727),
#  ('abov', 727),
#  ('pure', 727),
#  ('#', 726),
#  ('mini', 726),
#  ('bloatwar', 726),
#  ('singl', 724),
#  ('idea', 722),
#  ('record', 722),
#  ('flagship', 721),
#  ('error', 720),
#  ('code', 720),
#  ('releas', 718),
#  ('correct', 715),
#  ('/', 714),
#  ('comment', 713),
#  ('fan', 713),
#  ('websit', 713),
#  ('taken', 713),
#  ('five', 713),
#  ('true', 710),
#  ('stick', 709),
#  ('fun', 705),
#  ('jack', 698),
#  ('opinion', 697),
#  ('12', 696),
#  ('report', 695),
#  ('browser', 693),
#  ('.i', 693),
#  ('gotten', 692),
#  ('push', 692),
#  ('higher', 691),
#  ('locat', 689),
#  ('sensor', 687),
#  ('english', 685),
#  ('loos', 683),
#  ('backup', 683),
#  ('easier', 681),
#  ('anymor', 680),
#  ('four', 679),
#  ('s4', 677),
#  ('step', 666),
#  ('birthday', 664),
#  ('posit', 663),
#  ('commun', 663),
#  ('chanc', 662),
#  ('averag', 661),
#  ('pc', 660),
#  ('cricket', 656),
#  ('anywher', 655),
#  ('earbud', 654),
#  ('pull', 652),
#  ('g', 652),
#  ('choos', 651),
#  ('honor', 649),
#  ('brows', 648),
#  ('automat', 648),
#  ('tap', 648),
#  ('stream', 648),
#  ('level', 646),
#  ('media', 645),
#  ('vendedor', 645),
#  ('click', 643),
#  ('lol', 643),
#  ('ok.', 643),
#  ('fault', 643),
#  ('wall', 643),
#  ('gracia', 642),
#  ('physic', 642),
#  ('clearli', 642),
#  ('plenti', 641),
#  ('vendor', 640),
#  ('besid', 640),
#  ('head', 640),
#  ('una', 639),
#  ('truli', 639),
#  ('select', 638),
#  ('purpos', 638),
#  ('map', 636),
#  ('secur', 635),
#  ('indic', 635),
#  ('fm', 633),
#  ('track', 631),
#  ('none', 630),
#  ('moto', 630),
#  ('n', 629),
#  ('selfi', 629),
#  ('sorri', 628),
#  ('direct', 626),
#  ('heard', 626),
#  ('icon', 626),
#  ('kinda', 626),
#  ('garbag', 625),
#  ('nearli', 625),
#  ...]

# %%
def create_bow(documents, features, test):
    row = []
    col = []
    data = []

    labels = []

    for i in documents.index:
        review = BeforeTokenizationNormalizer.normalize(documents.iloc[i, 4])
        if(test == 1):
            label = documents.iloc[i, 5]
            labels.append(label)
        review_tokens = NltkTokenizer.tokenize(review)

        
        for token in set(review_tokens):
            if token not in features:
                continue
            row.append(i)
            col.append(features[token])
            data.append(1)
    return csr_matrix((data, (row, col)), shape=(len(documents), len(features))), labels

# %%
from scipy.sparse import csr_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score, precision_score, recall_score
# from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier

min_word_count = 50

common_words = list([k for k, v in words.most_common() if v > min_word_count])

feature_dict = {}
for word in common_words:
    feature_dict[word] = len(feature_dict)

print("Training classifier...")
print("1. create bow")
X_train, y_train = create_bow(train_data, feature_dict, 1)
print("2. list of classes")
list_of_labels = list(set(y_train))
print("3. classifier")
# classifier = RandomForestClassifier(n_estimators=1000, n_jobs=-1, random_state=23, verbose=True)
# classifier = SVC()
classifier = MLPClassifier(hidden_layer_sizes=(100,100,100), max_iter=500, alpha=0.0001,
                     solver='sgd', random_state=21,tol=0.000000001, verbose=True)
print("4. fit")
classifier.fit(X_train, y_train)

print("Testing...")
print("1. create bow")
X_test, y_test = create_bow(test_data, feature_dict, 0)
print("2. predict")
predicted = classifier.predict(X_test)

print("=================== Results ===================")
print(predicted)
# Out:
# C:\Users\Pawel\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# Training classifier...
# 1. create bow
# 2. list of classes
# 3. classifier
# 4. fit
# Iteration 1, loss = 1.22826789
# Iteration 2, loss = 0.94341045
# Iteration 3, loss = 0.84488436
# Iteration 4, loss = 0.80195711
# Iteration 5, loss = 0.77662253
# Iteration 6, loss = 0.75767748
# Iteration 7, loss = 0.74203179
# Iteration 8, loss = 0.72767900
# Iteration 9, loss = 0.71455300
# Iteration 10, loss = 0.70216694
# Iteration 11, loss = 0.69024219
# Iteration 12, loss = 0.67848783
# Iteration 13, loss = 0.66665284
# Iteration 14, loss = 0.65470344
# Iteration 15, loss = 0.64258551
# Iteration 16, loss = 0.63007006
# Iteration 17, loss = 0.61695216
# Iteration 18, loss = 0.60384606
# Iteration 19, loss = 0.59030274
# Iteration 20, loss = 0.57676512
# Iteration 21, loss = 0.56268966
# Iteration 22, loss = 0.54853531
# Iteration 23, loss = 0.53375672
# Iteration 24, loss = 0.51883586
# Iteration 25, loss = 0.50416211
# Iteration 26, loss = 0.48894718
# Iteration 27, loss = 0.47406218
# Iteration 28, loss = 0.45957661
# Iteration 29, loss = 0.44497255
# Iteration 30, loss = 0.43051865
# Iteration 31, loss = 0.41660162
# Iteration 32, loss = 0.40318229
# Iteration 33, loss = 0.38964287
# Iteration 34, loss = 0.37653746
# Iteration 35, loss = 0.36441091
# Iteration 36, loss = 0.35230094
# Iteration 37, loss = 0.34104231
# Iteration 38, loss = 0.32918460
# Iteration 39, loss = 0.31855568
# Iteration 40, loss = 0.30878777
# Iteration 41, loss = 0.29890410
# Iteration 42, loss = 0.28959721
# Iteration 43, loss = 0.28107027
# Iteration 44, loss = 0.27189580
# Iteration 45, loss = 0.26402955
# Iteration 46, loss = 0.25596341
# Iteration 47, loss = 0.24897323
# Iteration 48, loss = 0.24216557
# Iteration 49, loss = 0.23528241
# Iteration 50, loss = 0.22928637
# Iteration 51, loss = 0.22313789
# Iteration 52, loss = 0.21790520
# Iteration 53, loss = 0.21284950
# Iteration 54, loss = 0.20774002
# Iteration 55, loss = 0.20290810
# Iteration 56, loss = 0.19824252
# Iteration 57, loss = 0.19382510
# Iteration 58, loss = 0.18981430
# Iteration 59, loss = 0.18593788
# Iteration 60, loss = 0.18261519
# Iteration 61, loss = 0.17890542
# Iteration 62, loss = 0.17567524
# Iteration 63, loss = 0.17278791
# Iteration 64, loss = 0.16949567
# Iteration 65, loss = 0.16606001
# Iteration 66, loss = 0.16384344
# Iteration 67, loss = 0.16111381
# Iteration 68, loss = 0.16057367
# Iteration 69, loss = 0.15782359
# Iteration 70, loss = 0.15494521
# Iteration 71, loss = 0.15327368
# Iteration 72, loss = 0.15117805
# Iteration 73, loss = 0.14914684
# Iteration 74, loss = 0.14707795
# Iteration 75, loss = 0.14571058
# Iteration 76, loss = 0.14428261
# Iteration 77, loss = 0.14236641
# Iteration 78, loss = 0.14227271
# Iteration 79, loss = 0.13976220
# Iteration 80, loss = 0.13924421
# Iteration 81, loss = 0.13737149
# Iteration 82, loss = 0.13577008
# Iteration 83, loss = 0.13557473
# Iteration 84, loss = 0.13521207
# Iteration 85, loss = 0.13362850
# Iteration 86, loss = 0.13257694
# Iteration 87, loss = 0.13122188
# Iteration 88, loss = 0.13075743
# Iteration 89, loss = 0.12978136
# Iteration 90, loss = 0.12981810
# Iteration 91, loss = 0.12822882
# Iteration 92, loss = 0.12611951
# Iteration 93, loss = 0.12603790
# Iteration 94, loss = 0.12574905
# Iteration 95, loss = 0.12405327
# Iteration 96, loss = 0.12422851
# Iteration 97, loss = 0.12329812
# Iteration 98, loss = 0.12466884
# Iteration 99, loss = 0.12265560
# Iteration 100, loss = 0.12192294
# Iteration 101, loss = 0.12168031
# Iteration 102, loss = 0.12064799
# Iteration 103, loss = 0.11987947
# Iteration 104, loss = 0.11931154
# Iteration 105, loss = 0.11880536
# Iteration 106, loss = 0.11865463
# Iteration 107, loss = 0.11927102
# Iteration 108, loss = 0.11895141
# Iteration 109, loss = 0.11846265
# Iteration 110, loss = 0.11790857
# Iteration 111, loss = 0.11926775
# Iteration 112, loss = 0.11810992
# Iteration 113, loss = 0.11819659
# Training loss did not improve more than tol=0.000000 for two consecutive epochs. Stopping.
# Testing...
# 1. create bow
# 2. predict
# =================== Results ===================
# [5 5 5 ... 5 4 4]

# %%
test_data['Rating'] = predicted
results = test_data[['Id','Rating']]

# %%
results.to_csv("results.csv", index=False)
